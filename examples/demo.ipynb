# %%
# Ensure project root (OpenCEP) is on sys.path for imports like `from base.Pattern import Pattern`
import sys, os, pathlib

nb_dir = (
    pathlib.Path(__file__).parent if "__file__" in globals() else pathlib.Path.cwd()
)
project_root = str((nb_dir / "..").resolve())
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %% [markdown]
# # OpenCEP Demo
# This notebook demonstrates a simple ascending peak price pattern over Google stock updates.

# %%
from datetime import timedelta
from CEP import CEP
from base.Pattern import Pattern
from base.PatternStructure import SeqOperator, PrimitiveEventStructure
from condition.CompositeCondition import AndCondition
from condition.BaseRelationCondition import SmallerThanCondition
from condition.Condition import Variable, SimpleCondition
from stream.FileStream import FileInputStream, FileOutputStream
from plugin.stocks.Stocks import MetastockDataFormatter
import test

# %% [markdown]
# This pattern is looking for a short ascend in the Google peak prices:
# ```
# PATTERN SEQ(GoogleStockPriceUpdate a, GoogleStockPriceUpdate b, GoogleStockPriceUpdate c)
# WHERE a.PeakPrice < b.PeakPrice AND b.PeakPrice < c.PeakPrice
# WITHIN 3 minutes
# ```

# %%
googleAscendPattern = Pattern(
    SeqOperator(
        PrimitiveEventStructure("GOOG", "a"),
        PrimitiveEventStructure("GOOG", "b"),
        PrimitiveEventStructure("GOOG", "c"),
    ),
    AndCondition(
        SmallerThanCondition(
            Variable("a", lambda x: x["Peak Price"]),
            Variable("b", lambda x: x["Peak Price"]),
        ),
        SmallerThanCondition(
            Variable("b", lambda x: x["Peak Price"]),
            Variable("c", lambda x: x["Peak Price"]),
        ),
    ),
    timedelta(minutes=3),
)

# %% [markdown]
# Another way to define the above example is to use SimpleCondition and a lambda function:

# %%
googleAscendPattern = Pattern(
    SeqOperator(
        PrimitiveEventStructure("GOOG", "a"),
        PrimitiveEventStructure("GOOG", "b"),
        PrimitiveEventStructure("GOOG", "c"),
    ),
    SimpleCondition(
        Variable("a", lambda x: x["Peak Price"]),
        Variable("b", lambda x: x["Peak Price"]),
        Variable("c", lambda x: x["Peak Price"]),
        relation_op=lambda x, y, z: x < y < z,
    ),
    timedelta(minutes=3),
)

# %% [markdown]
# Creating a CEP object for monitoring the first pattern from the example above:

# %%
cep = CEP([googleAscendPattern])
# Out:
# Creating evaluation manager...
#  - Parallel execution: None
#  - Storage: None
#  - Using ParallelExecutionModes.SEQUENTIAL execution mode
# !!! Using default evaluation mechanism parameters...
# !!! Creating tree-based evaluation mechanism...
# Tree calling create_storage_unit with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# InternalNode creating storage: sort=False, sorting_key=None
# UnsortedPatternMatchStorage created with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# InternalNode creating storage: sort=False, sorting_key=None
# UnsortedPatternMatchStorage created with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode.create_storage_unit called with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode creating SortedPatternMatchStorage with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# SortedPatternMatchStorage created with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode.create_storage_unit called with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode creating SortedPatternMatchStorage with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# SortedPatternMatchStorage created with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode.create_storage_unit called with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# LeafNode creating SortedPatternMatchStorage with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# SortedPatternMatchStorage created with storage_params: TreeStorageParameters(sort_storage=False, attributes_priorities={}, clean_up_interval=10, prioritize_sorting_by_timestamp=True, enable_load_shedding=False, load_shedding_threshold=1000, load_shedding_drop_rate=0.1, load_shedding_strategy=random)
# Initialized CEP with the following parameters:
#  - Patterns: [
# Pattern structure: SEQ([GOOG a, GOOG b, GOOG c])
# Condition: [a, b, c]
# Time window: 0:03:00
#
# ]
#  - Evaluation Mechanism: None
#  - Parallel Execution: None
#  - Pattern Preprocessing: None
#  - Storage: None

# %% [markdown]
# Defining a new file-based event stream formatted according to Metastock 7 format:

# %%
events = FileInputStream("../test/EventFiles/NASDAQ_SHORT.txt")

# %% [markdown]
# Applying an existing CEP object on an event stream created above and storing the resulting pattern matches to a file:

# %%
cep.run(
    events,
    FileOutputStream("../test/demo/Matches", "output.txt"),
    MetastockDataFormatter(),
)
# Out:
# Starting CEP evaluation...
# Using generic file input stream processing
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010900, 'Opening Price': 532.04, 'Peak Price': 532.04, 'Lowest Price': 530.51, 'Close Price': 530.51, 'Volume': 17665}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:00:00, length of partial matches: 0
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010900, 'Opening Price': 532.04, 'Peak Price': 532.04, 'Lowest Price': 530.51, 'Close Price': 530.51, 'Volume': 17665}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:00:00, length of partial matches: 0
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010900, 'Opening Price': 532.04, 'Peak Price': 532.04, 'Lowest Price': 530.51, 'Close Price': 530.51, 'Volume': 17665}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:00:00, length of partial matches: 0
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010900, 'Opening Price': 532.04, 'Peak Price': 532.04, 'Lowest Price': 530.51, 'Close Price': 530.51, 'Volume': 17665}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010901, 'Opening Price': 530.53, 'Peak Price': 531.15, 'Lowest Price': 530.01, 'Close Price': 530.42, 'Volume': 14915}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:01:00, length of partial matches: 1
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010901, 'Opening Price': 530.53, 'Peak Price': 531.15, 'Lowest Price': 530.01, 'Close Price': 530.42, 'Volume': 14915}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:01:00, length of partial matches: 1
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010901, 'Opening Price': 530.53, 'Peak Price': 531.15, 'Lowest Price': 530.01, 'Close Price': 530.42, 'Volume': 14915}]
# UnsortedPatternMatchStorage.add() called! Total matches: 0
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:01:00, length of partial matches: 1
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010901, 'Opening Price': 530.53, 'Peak Price': 531.15, 'Lowest Price': 530.01, 'Close Price': 530.42, 'Volume': 14915}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010902, 'Opening Price': 530.33, 'Peak Price': 530.33, 'Lowest Price': 529.33, 'Close Price': 530.21, 'Volume': 15794}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:02:00, length of partial matches: 2
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010902, 'Opening Price': 530.33, 'Peak Price': 530.33, 'Lowest Price': 529.33, 'Close Price': 530.21, 'Volume': 15794}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:02:00, length of partial matches: 2
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010902, 'Opening Price': 530.33, 'Peak Price': 530.33, 'Lowest Price': 529.33, 'Close Price': 530.21, 'Volume': 15794}]
# UnsortedPatternMatchStorage.add() called! Total matches: 1
# UnsortedPatternMatchStorage.add() called! Total matches: 2
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:02:00, length of partial matches: 2
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010902, 'Opening Price': 530.33, 'Peak Price': 530.33, 'Lowest Price': 529.33, 'Close Price': 530.21, 'Volume': 15794}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010903, 'Opening Price': 530.08, 'Peak Price': 530.25, 'Lowest Price': 530, 'Close Price': 530.25, 'Volume': 7828}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:03:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010903, 'Opening Price': 530.08, 'Peak Price': 530.25, 'Lowest Price': 530, 'Close Price': 530.25, 'Volume': 7828}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:03:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010903, 'Opening Price': 530.08, 'Peak Price': 530.25, 'Lowest Price': 530, 'Close Price': 530.25, 'Volume': 7828}]
# UnsortedPatternMatchStorage.add() called! Total matches: 3
# UnsortedPatternMatchStorage.add() called! Total matches: 4
# UnsortedPatternMatchStorage.add() called! Total matches: 5
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:03:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010903, 'Opening Price': 530.08, 'Peak Price': 530.25, 'Lowest Price': 530, 'Close Price': 530.25, 'Volume': 7828}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010904, 'Opening Price': 530.05, 'Peak Price': 530.83, 'Lowest Price': 530, 'Close Price': 530.09, 'Volume': 6340}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:04:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010904, 'Opening Price': 530.05, 'Peak Price': 530.83, 'Lowest Price': 530, 'Close Price': 530.09, 'Volume': 6340}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:04:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010904, 'Opening Price': 530.05, 'Peak Price': 530.83, 'Lowest Price': 530, 'Close Price': 530.09, 'Volume': 6340}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:04:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010904, 'Opening Price': 530.05, 'Peak Price': 530.83, 'Lowest Price': 530, 'Close Price': 530.09, 'Volume': 6340}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010905, 'Opening Price': 530.1, 'Peak Price': 530.1, 'Lowest Price': 528.33, 'Close Price': 529.28, 'Volume': 8163}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:05:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010905, 'Opening Price': 530.1, 'Peak Price': 530.1, 'Lowest Price': 528.33, 'Close Price': 529.28, 'Volume': 8163}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:05:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010905, 'Opening Price': 530.1, 'Peak Price': 530.1, 'Lowest Price': 528.33, 'Close Price': 529.28, 'Volume': 8163}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:05:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010905, 'Opening Price': 530.1, 'Peak Price': 530.1, 'Lowest Price': 528.33, 'Close Price': 529.28, 'Volume': 8163}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010906, 'Opening Price': 529.26, 'Peak Price': 529.99, 'Lowest Price': 529.25, 'Close Price': 529.31, 'Volume': 3045}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:06:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010906, 'Opening Price': 529.26, 'Peak Price': 529.99, 'Lowest Price': 529.25, 'Close Price': 529.31, 'Volume': 3045}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:06:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010906, 'Opening Price': 529.26, 'Peak Price': 529.99, 'Lowest Price': 529.25, 'Close Price': 529.31, 'Volume': 3045}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:06:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010906, 'Opening Price': 529.26, 'Peak Price': 529.99, 'Lowest Price': 529.25, 'Close Price': 529.31, 'Volume': 3045}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010907, 'Opening Price': 529.32, 'Peak Price': 529.32, 'Lowest Price': 527, 'Close Price': 527, 'Volume': 7916}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:07:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010907, 'Opening Price': 529.32, 'Peak Price': 529.32, 'Lowest Price': 527, 'Close Price': 527, 'Volume': 7916}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:07:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010907, 'Opening Price': 529.32, 'Peak Price': 529.32, 'Lowest Price': 527, 'Close Price': 527, 'Volume': 7916}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:07:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010907, 'Opening Price': 529.32, 'Peak Price': 529.32, 'Lowest Price': 527, 'Close Price': 527, 'Volume': 7916}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010908, 'Opening Price': 526.74, 'Peak Price': 528.99, 'Lowest Price': 526.74, 'Close Price': 528.4, 'Volume': 9485}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:08:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010908, 'Opening Price': 526.74, 'Peak Price': 528.99, 'Lowest Price': 526.74, 'Close Price': 528.4, 'Volume': 9485}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:08:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010908, 'Opening Price': 526.74, 'Peak Price': 528.99, 'Lowest Price': 526.74, 'Close Price': 528.4, 'Volume': 9485}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:08:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010908, 'Opening Price': 526.74, 'Peak Price': 528.99, 'Lowest Price': 526.74, 'Close Price': 528.4, 'Volume': 9485}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010909, 'Opening Price': 528, 'Peak Price': 530, 'Lowest Price': 528, 'Close Price': 529.71, 'Volume': 10370}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:09:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010909, 'Opening Price': 528, 'Peak Price': 530, 'Lowest Price': 528, 'Close Price': 529.71, 'Volume': 10370}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:09:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010909, 'Opening Price': 528, 'Peak Price': 530, 'Lowest Price': 528, 'Close Price': 529.71, 'Volume': 10370}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:09:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010909, 'Opening Price': 528, 'Peak Price': 530, 'Lowest Price': 528, 'Close Price': 529.71, 'Volume': 10370}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010910, 'Opening Price': 529.97, 'Peak Price': 530, 'Lowest Price': 528.79, 'Close Price': 529.24, 'Volume': 20773}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:10:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010910, 'Opening Price': 529.97, 'Peak Price': 530, 'Lowest Price': 528.79, 'Close Price': 529.24, 'Volume': 20773}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:10:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010910, 'Opening Price': 529.97, 'Peak Price': 530, 'Lowest Price': 528.79, 'Close Price': 529.24, 'Volume': 20773}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:10:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010910, 'Opening Price': 529.97, 'Peak Price': 530, 'Lowest Price': 528.79, 'Close Price': 529.24, 'Volume': 20773}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010911, 'Opening Price': 529.31, 'Peak Price': 529.38, 'Lowest Price': 528.28, 'Close Price': 529, 'Volume': 8038}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:11:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010911, 'Opening Price': 529.31, 'Peak Price': 529.38, 'Lowest Price': 528.28, 'Close Price': 529, 'Volume': 8038}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:11:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010911, 'Opening Price': 529.31, 'Peak Price': 529.38, 'Lowest Price': 528.28, 'Close Price': 529, 'Volume': 8038}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:11:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010911, 'Opening Price': 529.31, 'Peak Price': 529.38, 'Lowest Price': 528.28, 'Close Price': 529, 'Volume': 8038}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010912, 'Opening Price': 529, 'Peak Price': 529.2, 'Lowest Price': 529, 'Close Price': 529.01, 'Volume': 15050}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:12:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010912, 'Opening Price': 529, 'Peak Price': 529.2, 'Lowest Price': 529, 'Close Price': 529.01, 'Volume': 15050}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:12:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010912, 'Opening Price': 529, 'Peak Price': 529.2, 'Lowest Price': 529, 'Close Price': 529.01, 'Volume': 15050}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:12:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010912, 'Opening Price': 529, 'Peak Price': 529.2, 'Lowest Price': 529, 'Close Price': 529.01, 'Volume': 15050}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010913, 'Opening Price': 528.83, 'Peak Price': 528.83, 'Lowest Price': 528.19, 'Close Price': 528.67, 'Volume': 3335}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:13:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010913, 'Opening Price': 528.83, 'Peak Price': 528.83, 'Lowest Price': 528.19, 'Close Price': 528.67, 'Volume': 3335}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:13:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010913, 'Opening Price': 528.83, 'Peak Price': 528.83, 'Lowest Price': 528.19, 'Close Price': 528.67, 'Volume': 3335}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:13:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010913, 'Opening Price': 528.83, 'Peak Price': 528.83, 'Lowest Price': 528.19, 'Close Price': 528.67, 'Volume': 3335}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010914, 'Opening Price': 528.84, 'Peak Price': 528.98, 'Lowest Price': 528.31, 'Close Price': 528.31, 'Volume': 2000}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:14:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010914, 'Opening Price': 528.84, 'Peak Price': 528.98, 'Lowest Price': 528.31, 'Close Price': 528.31, 'Volume': 2000}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:14:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010914, 'Opening Price': 528.84, 'Peak Price': 528.98, 'Lowest Price': 528.31, 'Close Price': 528.31, 'Volume': 2000}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:14:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010914, 'Opening Price': 528.84, 'Peak Price': 528.98, 'Lowest Price': 528.31, 'Close Price': 528.31, 'Volume': 2000}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010915, 'Opening Price': 528.65, 'Peak Price': 528.81, 'Lowest Price': 528.5, 'Close Price': 528.51, 'Volume': 700}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:15:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010915, 'Opening Price': 528.65, 'Peak Price': 528.81, 'Lowest Price': 528.5, 'Close Price': 528.51, 'Volume': 700}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:15:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010915, 'Opening Price': 528.65, 'Peak Price': 528.81, 'Lowest Price': 528.5, 'Close Price': 528.51, 'Volume': 700}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:15:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010915, 'Opening Price': 528.65, 'Peak Price': 528.81, 'Lowest Price': 528.5, 'Close Price': 528.51, 'Volume': 700}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010916, 'Opening Price': 528.9, 'Peak Price': 531.47, 'Lowest Price': 528.8, 'Close Price': 531.26, 'Volume': 17069}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:16:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010916, 'Opening Price': 528.9, 'Peak Price': 531.47, 'Lowest Price': 528.8, 'Close Price': 531.26, 'Volume': 17069}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:16:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010916, 'Opening Price': 528.9, 'Peak Price': 531.47, 'Lowest Price': 528.8, 'Close Price': 531.26, 'Volume': 17069}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:16:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010916, 'Opening Price': 528.9, 'Peak Price': 531.47, 'Lowest Price': 528.8, 'Close Price': 531.26, 'Volume': 17069}]
# UnsortedPatternMatchStorage.add() called! Total matches: 0
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010913, 'Opening Price': 528.83, 'Peak Price': 528.83, 'Lowest Price': 528.19, 'Close Price': 528.67, 'Volume': 3335}
# {'Stock Ticker': 'GOOG', 'Date': 200802010914, 'Opening Price': 528.84, 'Peak Price': 528.98, 'Lowest Price': 528.31, 'Close Price': 528.31, 'Volume': 2000}
# {'Stock Ticker': 'GOOG', 'Date': 200802010916, 'Opening Price': 528.9, 'Peak Price': 531.47, 'Lowest Price': 528.8, 'Close Price': 531.26, 'Volume': 17069}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010917, 'Opening Price': 530.96, 'Peak Price': 531.47, 'Lowest Price': 530.35, 'Close Price': 530.35, 'Volume': 8625}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:17:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010917, 'Opening Price': 530.96, 'Peak Price': 531.47, 'Lowest Price': 530.35, 'Close Price': 530.35, 'Volume': 8625}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:17:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010917, 'Opening Price': 530.96, 'Peak Price': 531.47, 'Lowest Price': 530.35, 'Close Price': 530.35, 'Volume': 8625}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:17:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010917, 'Opening Price': 530.96, 'Peak Price': 531.47, 'Lowest Price': 530.35, 'Close Price': 530.35, 'Volume': 8625}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:18:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:18:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:18:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:19:00, length of partial matches: 13
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:19:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:19:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:20:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:20:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:20:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}]
# UnsortedPatternMatchStorage.add() called! Total matches: 1
# UnsortedPatternMatchStorage.add() called! Total matches: 2
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010917, 'Opening Price': 530.96, 'Peak Price': 531.47, 'Lowest Price': 530.35, 'Close Price': 530.35, 'Volume': 8625}
# {'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}
# {'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}
#
#
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}
# {'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}
# {'Stock Ticker': 'GOOG', 'Date': 200802010920, 'Opening Price': 531.83, 'Peak Price': 532.79, 'Lowest Price': 531.67, 'Close Price': 531.95, 'Volume': 10250}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010921, 'Opening Price': 531.9, 'Peak Price': 531.9, 'Lowest Price': 529.84, 'Close Price': 530.37, 'Volume': 3200}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:21:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010921, 'Opening Price': 531.9, 'Peak Price': 531.9, 'Lowest Price': 529.84, 'Close Price': 530.37, 'Volume': 3200}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:21:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010921, 'Opening Price': 531.9, 'Peak Price': 531.9, 'Lowest Price': 529.84, 'Close Price': 530.37, 'Volume': 3200}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:21:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010921, 'Opening Price': 531.9, 'Peak Price': 531.9, 'Lowest Price': 529.84, 'Close Price': 530.37, 'Volume': 3200}]
# UnsortedPatternMatchStorage.add() called! Total matches: 3
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010918, 'Opening Price': 530.36, 'Peak Price': 531, 'Lowest Price': 530.35, 'Close Price': 530.36, 'Volume': 7300}
# {'Stock Ticker': 'GOOG', 'Date': 200802010919, 'Opening Price': 530.74, 'Peak Price': 531.65, 'Lowest Price': 530.74, 'Close Price': 531.61, 'Volume': 7399}
# {'Stock Ticker': 'GOOG', 'Date': 200802010921, 'Opening Price': 531.9, 'Peak Price': 531.9, 'Lowest Price': 529.84, 'Close Price': 530.37, 'Volume': 3200}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010922, 'Opening Price': 529.97, 'Peak Price': 529.97, 'Lowest Price': 529.5, 'Close Price': 529.5, 'Volume': 8230}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:22:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010922, 'Opening Price': 529.97, 'Peak Price': 529.97, 'Lowest Price': 529.5, 'Close Price': 529.5, 'Volume': 8230}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:22:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010922, 'Opening Price': 529.97, 'Peak Price': 529.97, 'Lowest Price': 529.5, 'Close Price': 529.5, 'Volume': 8230}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:22:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010922, 'Opening Price': 529.97, 'Peak Price': 529.97, 'Lowest Price': 529.5, 'Close Price': 529.5, 'Volume': 8230}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010923, 'Opening Price': 529.38, 'Peak Price': 529.45, 'Lowest Price': 529.01, 'Close Price': 529.4, 'Volume': 3000}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:23:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010923, 'Opening Price': 529.38, 'Peak Price': 529.45, 'Lowest Price': 529.01, 'Close Price': 529.4, 'Volume': 3000}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:23:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010923, 'Opening Price': 529.38, 'Peak Price': 529.45, 'Lowest Price': 529.01, 'Close Price': 529.4, 'Volume': 3000}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:23:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010923, 'Opening Price': 529.38, 'Peak Price': 529.45, 'Lowest Price': 529.01, 'Close Price': 529.4, 'Volume': 3000}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010924, 'Opening Price': 529, 'Peak Price': 529.49, 'Lowest Price': 529, 'Close Price': 529.49, 'Volume': 2133}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:24:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010924, 'Opening Price': 529, 'Peak Price': 529.49, 'Lowest Price': 529, 'Close Price': 529.49, 'Volume': 2133}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:24:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010924, 'Opening Price': 529, 'Peak Price': 529.49, 'Lowest Price': 529, 'Close Price': 529.49, 'Volume': 2133}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:24:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010924, 'Opening Price': 529, 'Peak Price': 529.49, 'Lowest Price': 529, 'Close Price': 529.49, 'Volume': 2133}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010925, 'Opening Price': 529.46, 'Peak Price': 529.46, 'Lowest Price': 529.02, 'Close Price': 529.4, 'Volume': 700}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:25:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010925, 'Opening Price': 529.46, 'Peak Price': 529.46, 'Lowest Price': 529.02, 'Close Price': 529.4, 'Volume': 700}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:25:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010925, 'Opening Price': 529.46, 'Peak Price': 529.46, 'Lowest Price': 529.02, 'Close Price': 529.4, 'Volume': 700}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:25:00, length of partial matches: 8
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010925, 'Opening Price': 529.46, 'Peak Price': 529.46, 'Lowest Price': 529.02, 'Close Price': 529.4, 'Volume': 700}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010926, 'Opening Price': 529.26, 'Peak Price': 529.43, 'Lowest Price': 527.63, 'Close Price': 528.55, 'Volume': 5130}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:26:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010926, 'Opening Price': 529.26, 'Peak Price': 529.43, 'Lowest Price': 527.63, 'Close Price': 528.55, 'Volume': 5130}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:26:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010926, 'Opening Price': 529.26, 'Peak Price': 529.43, 'Lowest Price': 527.63, 'Close Price': 528.55, 'Volume': 5130}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:26:00, length of partial matches: 9
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010926, 'Opening Price': 529.26, 'Peak Price': 529.43, 'Lowest Price': 527.63, 'Close Price': 528.55, 'Volume': 5130}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010927, 'Opening Price': 528.47, 'Peak Price': 529.26, 'Lowest Price': 528.47, 'Close Price': 528.53, 'Volume': 6480}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:27:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010927, 'Opening Price': 528.47, 'Peak Price': 529.26, 'Lowest Price': 528.47, 'Close Price': 528.53, 'Volume': 6480}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:27:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010927, 'Opening Price': 528.47, 'Peak Price': 529.26, 'Lowest Price': 528.47, 'Close Price': 528.53, 'Volume': 6480}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:27:00, length of partial matches: 10
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010927, 'Opening Price': 528.47, 'Peak Price': 529.26, 'Lowest Price': 528.47, 'Close Price': 528.53, 'Volume': 6480}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:28:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:28:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:28:00, length of partial matches: 11
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:29:00, length of partial matches: 13
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:29:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:29:00, length of partial matches: 12
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}]
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:30:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:30:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:30:00, length of partial matches: 3
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}]
# UnsortedPatternMatchStorage.add() called! Total matches: 4
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}
# {'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}
# {'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:31:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:31:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}]
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# UnsortedPatternMatchStorage.add() called! Total matches: 10
# UnsortedPatternMatchStorage.add() called! Total matches: 11
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:31:00, length of partial matches: 4
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}]
# UnsortedPatternMatchStorage.add() called! Total matches: 5
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010928, 'Opening Price': 528.72, 'Peak Price': 528.84, 'Lowest Price': 526.81, 'Close Price': 528.01, 'Volume': 16199}
# {'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}
# {'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:32:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:32:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}]
# UnsortedPatternMatchStorage.add() called! Total matches: 12
# UnsortedPatternMatchStorage.add() called! Total matches: 13
# UnsortedPatternMatchStorage.add() called! Total matches: 14
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:32:00, length of partial matches: 5
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}]
# UnsortedPatternMatchStorage.add() called! Total matches: 6
# UnsortedPatternMatchStorage.add() called! Total matches: 7
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}
# {'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}
# {'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}
#
#
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010929, 'Opening Price': 528.01, 'Peak Price': 528.94, 'Lowest Price': 527.1, 'Close Price': 528.94, 'Volume': 7100}
# {'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}
# {'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}
#
#
# Playing new event on tree: {'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}, trying to find matches
# Playing new event. Event types listeners: {'GOOG': [<tree.nodes.LeafNode.LeafNode object at 0x000001EB3420CD10>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D490>, <tree.nodes.LeafNode.LeafNode object at 0x000001EB3420D970>]}
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:33:00, length of partial matches: 7
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}]
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:33:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}]
# UnsortedPatternMatchStorage.add() called! Total matches: 15
# UnsortedPatternMatchStorage.add() called! Total matches: 16
# UnsortedPatternMatchStorage.add() called! Total matches: 17
# SortedPatternMatchStorage.add() called Key: 2008-02-01 09:33:00, length of partial matches: 6
# Current events in pattern match: [{'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}]
# UnsortedPatternMatchStorage.add() called! Total matches: 8
# UnsortedPatternMatchStorage.add() called! Total matches: 9
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010930, 'Opening Price': 529.02, 'Peak Price': 529.46, 'Lowest Price': 525.25, 'Close Price': 526, 'Volume': 295504}
# {'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}
# {'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}
#
#
# Found match: {'Stock Ticker': 'GOOG', 'Date': 200802010931, 'Opening Price': 525.75, 'Peak Price': 529.24, 'Lowest Price': 525.72, 'Close Price': 528.97, 'Volume': 105641}
# {'Stock Ticker': 'GOOG', 'Date': 200802010932, 'Opening Price': 529.15, 'Peak Price': 534.84, 'Lowest Price': 528.9, 'Close Price': 534.4, 'Volume': 158783}
# {'Stock Ticker': 'GOOG', 'Date': 200802010933, 'Opening Price': 534.54, 'Peak Price': 536.67, 'Lowest Price': 533.4, 'Close Price': 534.15, 'Volume': 160588}
#
#
# median latency: 0.0000
# p95 latency: 0.0002
# 0.090934
